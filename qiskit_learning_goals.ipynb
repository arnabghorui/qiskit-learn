# %% [markdown]
# Here I note down my learning goals from qiskit. Any resource that I get will be added here with ther given context. Happy learning!

# %% [markdown]
# ## 1)  Measurements: Question is how to perform/simulate measurement in qiskit? The next question will be, how to perform a measurement in different basis?

# %%
from qiskit import *

# %%
# create a new Quantum Circuit
qc = QuantumCircuit(2,2)
qc.h(0) # apply Hadamard gate to qubit 0
qc.cx(0, 1) # apply CNOT gate to qubit 0 and 1 with 0 as control and 1 as target

# %%
qc.draw('mpl')

# %%
qc.measure([0,1], [0,1])
qc.draw('mpl')

# %%
from qiskit_aer import QasmSimulator, StatevectorSimulator
simulator = QasmSimulator()

# %%
job = simulator.run(qc, shots=10000)
result = job.result()
counts = result.get_counts(qc)

from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
print(counts)
# print("Probability of measuring 00 is:", counts['00']/10000, "and 01 is:", counts['01']/10000)
# Out:
# {'11': 4982, '00': 5018}
